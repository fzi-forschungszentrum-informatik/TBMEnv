# %% [markdown]
# # Data Preparation for Scenario 2

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in /opt/conda/lib/python3.10/site-packages (1.1.4)
# Requirement already satisfied: convertdate>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from prophet) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from prophet) (2.8.2)
# Requirement already satisfied: pandas>=1.0.4 in /opt/conda/lib/python3.10/site-packages (from prophet) (1.4.2)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/conda/lib/python3.10/site-packages (from prophet) (4.64.0)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.10/site-packages (from prophet) (1.22.4)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /opt/conda/lib/python3.10/site-packages (from prophet) (1.1.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from prophet) (3.5.2)
# Requirement already satisfied: holidays>=0.25 in /opt/conda/lib/python3.10/site-packages (from prophet) (0.27.1)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from prophet) (5.8.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /opt/conda/lib/python3.10/site-packages (from prophet) (0.0.9)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.10/site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->prophet) (2022.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /opt/conda/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (9.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generic Settings and Imports

# %%
from pathlib import Path

import GPy
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from prophet import Prophet

# %%
# %matplotlib inline

matplotlib.rcParams.update({
    # for nice exports to LaTeX
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    # standard figure size nice for A4 pages.
    # 'figure.figsize': [6.3, 3.5],
    # standard figure size for double columns
    'figure.figsize': [3.3, 1.8],
    'font.size': 9,
    # Makes plotted stuff larger in notebook
    'figure.dpi': 100,
})

# %% [markdown]
# ## Generic Helpers

# %%
def add_minute_of_day(df):
    df["minutes of day"] = df.index.hour * 60 + df.index.minute
    return df

# %%
def save_ax_for_latex(ax, fn):
    """
    Allows saving the stuff returned by a pandas plot.
    """
    fig = ax.get_figure()
    plt.tight_layout()
    
    base_dir = Path().absolute()

    # Save somewhere else on David's machine.
    if "diss" in str(base_dir):
        base_dir = Path(str(base_dir).split("diss")[0])
        base_dir = base_dir / "diss" / "generated_graphics"
        
    fig.savefig(str(base_dir / fn), bbox_inches='tight')

# %% [markdown]
# ## Load the Raw Data

# %%
data_url = "https://raw.githubusercontent.com/fzi-forschungszentrum-informatik/tropical_precooling_environment/master/tropical_precooling/data/building_measurements.csv"
raw_data = pd.read_csv(data_url, parse_dates=True, index_col=0)
raw_data
# Out:
#                      Outside air temperature    CO2  Supply air temp  \
# 2014-01-03 04:02:30                     26.6  558.6             12.0
# 2014-01-03 04:07:30                     26.6  557.1             12.0
# 2014-01-03 04:12:30                     26.6  556.5             12.0
# 2014-01-03 04:17:30                     26.7  560.1             12.0
# 2014-01-03 04:22:30                     26.7  559.1             12.0
# ...                                      ...    ...              ...
# 2014-12-24 16:37:30                     29.7  603.9             13.0
# 2014-12-24 16:42:30                     29.5  603.4             13.0
# 2014-12-24 16:47:30                     29.5  603.1             13.0
# 2014-12-24 16:52:30                     29.6  604.5             13.0
# 2014-12-24 16:57:30                     29.8  605.1             13.0
#
#                      Zone temperature
# 2014-01-03 04:02:30              28.2
# 2014-01-03 04:07:30              28.2
# 2014-01-03 04:12:30              28.2
# 2014-01-03 04:17:30              28.2
# 2014-01-03 04:22:30              28.2
# ...                               ...
# 2014-12-24 16:37:30              24.5
# 2014-12-24 16:42:30              24.5
# 2014-12-24 16:47:30              24.5
# 2014-12-24 16:52:30              24.6
# 2014-12-24 16:57:30              24.6
#
# [18720 rows x 4 columns]

# %% [markdown]
# ## Analysis of the zone temperature
# Display the zone temperature vs. hours of day.

# %%
data_for_ts_analsis = raw_data[["Zone temperature"]].copy()
data_for_ts_analsis["hour_of_day"] = data_for_ts_analsis.index.hour + data_for_ts_analsis.index.minute / 60.
data_for_ts_analsis = data_for_ts_analsis.values.reshape(-1, 156, 2)
T_z = data_for_ts_analsis[..., 0]
hour_of_day = data_for_ts_analsis[..., 1]
fig = plt.figure(figsize=(24, 12))
for i in range(data_for_ts_analsis.shape[0]): 
    _ = plt.plot(hour_of_day[i], T_z[i])
_ = plt.axvline(x = 6.75, color = 'r')

# %% [markdown]
# ### Finding:
# We can find the following information in this plot:
# * There are at least 4 days (red, red, yellow and green) in which the AC hasn't worked as expected.
# * The AC doesn't seem to be time controlled as the times the AC is switched on vary slightly. However, 6:45 am switch on time (the red vertical bar) seems to be a sane compromise.
# * AC seems to be off in the morning hours before ~ 6:45 am.

# %% [markdown]
# ## Prepare the Data for the Predictions
# In particular add the minutes of day as a feature for the forecast of the supply air temperature

# %%
data = add_minute_of_day(raw_data.copy())
data
# Out:
#                      Outside air temperature    CO2  Supply air temp  \
# 2014-01-03 04:02:30                     26.6  558.6             12.0
# 2014-01-03 04:07:30                     26.6  557.1             12.0
# 2014-01-03 04:12:30                     26.6  556.5             12.0
# 2014-01-03 04:17:30                     26.7  560.1             12.0
# 2014-01-03 04:22:30                     26.7  559.1             12.0
# ...                                      ...    ...              ...
# 2014-12-24 16:37:30                     29.7  603.9             13.0
# 2014-12-24 16:42:30                     29.5  603.4             13.0
# 2014-12-24 16:47:30                     29.5  603.1             13.0
# 2014-12-24 16:52:30                     29.6  604.5             13.0
# 2014-12-24 16:57:30                     29.8  605.1             13.0
#
#                      Zone temperature  minutes of day
# 2014-01-03 04:02:30              28.2             242
# 2014-01-03 04:07:30              28.2             247
# 2014-01-03 04:12:30              28.2             252
# 2014-01-03 04:17:30              28.2             257
# 2014-01-03 04:22:30              28.2             262
# ...                               ...             ...
# 2014-12-24 16:37:30              24.5             997
# 2014-12-24 16:42:30              24.5            1002
# 2014-12-24 16:47:30              24.5            1007
# 2014-12-24 16:52:30              24.6            1012
# 2014-12-24 16:57:30              24.6            1017
#
# [18720 rows x 5 columns]

# %%
_ = pd.plotting.scatter_matrix(data, figsize=(10,10))

# %% [markdown]
# ## Train-Test Split as in the Tropcial Precooling Env

# %%
train_selector = data.index.month >= 7
predict_selector = data.index.month > 0
metrics_selector = data.index.month < 7

# %% [markdown]
# ## Predict the supply air temperature

# %%
# all other data is not available in advance.
sat_features = data[["minutes of day", "Outside air temperature"]]

# normalize data
sat_features = (sat_features - sat_features.mean()) / sat_features.std()

X_train = sat_features[train_selector].values
print(X_train.shape, X_train.mean(), X_train.std())
X_predict = sat_features[predict_selector].values
print(X_predict.shape, X_predict.mean(), X_predict.std())

Y_train = data[["Supply air temp"]].loc[train_selector].values
print(Y_train.shape, Y_train.mean(), Y_train.std())
Y_true = data[["Supply air temp"]].loc[predict_selector].values
print(Y_true.shape, Y_true.mean(), Y_true.std())
# Out:
# (8892, 2) 0.09711556215033593 1.0703876998066242
# (18720, 2) 2.679414145447489e-14 0.9999732902415841
# (8892, 1) 13.520040485829961 1.215026660997567
# (18720, 1) 13.52735576923077 1.301771498260991

# %%
kernel = GPy.kern.RBF(input_dim=2, variance=1., lengthscale=1., ARD=True)
mean_function = GPy.mappings.Constant(input_dim=2, output_dim=1, value=Y_train.mean())
gp = GPy.models.GPRegression(X_train, Y_train, kernel, mean_function=mean_function)

# %%
_ = gp.optimize(messages=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
Y_predict, Y_predict_var = gp.predict(X_predict)

# %%
Y_predict_std = np.sqrt(Y_predict_var)
sat_prediction = pd.DataFrame(
    index=data.index[predict_selector],
    data={
        "sat_fct_mean": Y_predict[:, 0],
        "sat_fct_lower": Y_predict[:, 0] - 2 * Y_predict_std[:, 0],
        "sat_fct_upper": Y_predict[:, 0] + 2 * Y_predict_std[:, 0],
    },
)
sat_prediction
# Out:
#                      sat_fct_mean  sat_fct_lower  sat_fct_upper
# 2014-01-03 04:02:30     13.079761      11.009006      15.150516
# 2014-01-03 04:07:30     13.066577      11.010313      15.122841
# 2014-01-03 04:12:30     13.056364      11.009703      15.103025
# 2014-01-03 04:17:30     13.072988      11.020608      15.125368
# 2014-01-03 04:22:30     13.075183      11.026513      15.123854
# ...                           ...            ...            ...
# 2014-12-24 16:37:30     12.984793      10.959290      15.010297
# 2014-12-24 16:42:30     13.014742      10.989759      15.039724
# 2014-12-24 16:47:30     13.023483      10.993116      15.053849
# 2014-12-24 16:52:30     13.031043      10.989980      15.072105
# 2014-12-24 16:57:30     13.052815      11.001304      15.104327
#
# [18720 rows x 3 columns]

# %%
sat_metrics = pd.DataFrame(
    index=data.index,
    data={
        "MAE": abs(data["Supply air temp"] - sat_prediction["sat_fct_mean"]),
        "MAPE": (abs(data["Supply air temp"] - sat_prediction["sat_fct_mean"])/sat_prediction["sat_fct_mean"]),
    },
)
sat_metrics = sat_metrics[metrics_selector]
ax = sat_metrics.plot(secondary_y=["MAPE"])

# %%
sat_metrics
# Out:
#                           MAE      MAPE
# 2014-01-03 04:02:30  1.079761  0.082552
# 2014-01-03 04:07:30  1.066577  0.081626
# 2014-01-03 04:12:30  1.056364  0.080908
# 2014-01-03 04:17:30  1.072988  0.082077
# 2014-01-03 04:22:30  1.075183  0.082231
# ...                       ...       ...
# 2014-04-04 16:37:30  0.136460  0.010388
# 2014-04-04 16:42:30  0.095510  0.007293
# 2014-04-04 16:47:30  0.091833  0.007015
# 2014-04-04 16:52:30  0.090619  0.006922
# 2014-04-04 16:57:30  0.083709  0.006398
#
# [9828 rows x 2 columns]

# %%
sat_metrics.groupby(lambda x: x.time()).mean().plot(secondary_y=["MAPE"])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
sat_metrics.mean()
# Out:
# MAE     0.968163
# MAPE    0.069357
# dtype: float64

# %% [markdown]
# ## Forecast for $CO_2$ values

# %%
train_data = pd.DataFrame(
    data={
        "ds": data[train_selector].index,
        "y": data[train_selector]["CO2"]
    }
)
predict_data = pd.DataFrame(
    data={
        "ds": data[predict_selector].index,
    }
)

co2_model = Prophet(growth="flat", n_changepoints=0, yearly_seasonality=False, interval_width=0.954)
_ = co2_model.fit(train_data)
# Out:
# 15:36:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:32 - cmdstanpy - INFO - Chain [1] done processing

# %%
prophet_out = co2_model.predict(predict_data)

# %%
co2_model.plot(prophet_out)

# %%
co2_model.plot_components(prophet_out)

# %%
prophet_out
# Out:
#                        ds       trend  yhat_lower  yhat_upper  trend_lower  \
# 0     2014-01-03 04:02:30  696.952836  526.068434  652.681593   696.952836
# 1     2014-01-03 04:07:30  696.952836  525.632715  654.406992   696.952836
# 2     2014-01-03 04:12:30  696.952836  530.270074  665.326650   696.952836
# 3     2014-01-03 04:17:30  696.952836  535.553595  665.936355   696.952836
# 4     2014-01-03 04:22:30  696.952836  535.169819  663.173002   696.952836
# ...                   ...         ...         ...         ...          ...
# 18715 2014-12-24 16:37:30  696.952836  706.495437  845.736788   696.952836
# 18716 2014-12-24 16:42:30  696.952836  706.434503  839.562047   696.952836
# 18717 2014-12-24 16:47:30  696.952836  708.667064  837.714528   696.952836
# 18718 2014-12-24 16:52:30  696.952836  708.443738  841.939449   696.952836
# 18719 2014-12-24 16:57:30  696.952836  708.310219  840.276095   696.952836
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 0       696.952836     -106.980532           -106.980532
# 1       696.952836     -104.159187           -104.159187
# 2       696.952836     -101.672112           -101.672112
# 3       696.952836      -99.517637            -99.517637
# 4       696.952836      -97.691407            -97.691407
# ...            ...             ...                   ...
# 18715   696.952836       75.526299             75.526299
# 18716   696.952836       76.120979             76.120979
# 18717   696.952836       76.831399             76.831399
# 18718   696.952836       77.670512             77.670512
# 18719   696.952836       78.650881             78.650881
#
#        additive_terms_upper       daily  daily_lower  daily_upper     weekly  \
# 0               -106.980532 -118.107849  -118.107849  -118.107849  11.127318
# 1               -104.159187 -115.074983  -115.074983  -115.074983  10.915796
# 2               -101.672112 -112.374772  -112.374772  -112.374772  10.702660
# 3                -99.517637 -110.005561  -110.005561  -110.005561  10.487924
# 4                -97.691407 -107.963006  -107.963006  -107.963006  10.271599
# ...                     ...         ...          ...          ...        ...
# 18715             75.526299   84.863046    84.863046    84.863046  -9.336747
# 18716             76.120979   85.459555    85.459555    85.459555  -9.338576
# 18717             76.831399   86.170495    86.170495    86.170495  -9.339096
# 18718             77.670512   87.008816    87.008816    87.008816  -9.338304
# 18719             78.650881   87.987077    87.987077    87.987077  -9.336196
#
#        weekly_lower  weekly_upper  multiplicative_terms  \
# 0         11.127318     11.127318                   0.0
# 1         10.915796     10.915796                   0.0
# 2         10.702660     10.702660                   0.0
# 3         10.487924     10.487924                   0.0
# 4         10.271599     10.271599                   0.0
# ...             ...           ...                   ...
# 18715     -9.336747     -9.336747                   0.0
# 18716     -9.338576     -9.338576                   0.0
# 18717     -9.339096     -9.339096                   0.0
# 18718     -9.338304     -9.338304                   0.0
# 18719     -9.336196     -9.336196                   0.0
#
#        multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                             0.0                         0.0  589.972304
# 1                             0.0                         0.0  592.793649
# 2                             0.0                         0.0  595.280724
# 3                             0.0                         0.0  597.435199
# 4                             0.0                         0.0  599.261428
# ...                           ...                         ...         ...
# 18715                         0.0                         0.0  772.479135
# 18716                         0.0                         0.0  773.073815
# 18717                         0.0                         0.0  773.784234
# 18718                         0.0                         0.0  774.623347
# 18719                         0.0                         0.0  775.603716
#
# [18720 rows x 19 columns]

# %%
co2_prediction = pd.DataFrame(
    index=prophet_out["ds"].values,
    data={
        "co2_fct_mean": prophet_out["yhat"].values,
        "co2_fct_upper": prophet_out["yhat_upper"].values,
        "co2_fct_lower": prophet_out["yhat_lower"].values,
    },
)
co2_prediction
# Out:
#                      co2_fct_mean  co2_fct_upper  co2_fct_lower
# 2014-01-03 04:02:30    589.972304     652.681593     526.068434
# 2014-01-03 04:07:30    592.793649     654.406992     525.632715
# 2014-01-03 04:12:30    595.280724     665.326650     530.270074
# 2014-01-03 04:17:30    597.435199     665.936355     535.553595
# 2014-01-03 04:22:30    599.261428     663.173002     535.169819
# ...                           ...            ...            ...
# 2014-12-24 16:37:30    772.479135     845.736788     706.495437
# 2014-12-24 16:42:30    773.073815     839.562047     706.434503
# 2014-12-24 16:47:30    773.784234     837.714528     708.667064
# 2014-12-24 16:52:30    774.623347     841.939449     708.443738
# 2014-12-24 16:57:30    775.603716     840.276095     708.310219
#
# [18720 rows x 3 columns]

# %%
co2_metrics = pd.DataFrame(
    index=data.index[predict_selector],
    data={
        "MAE": abs(data["CO2"] - co2_prediction["co2_fct_mean"]),
        "MAPE": (abs(data["CO2"] - co2_prediction["co2_fct_mean"])/co2_prediction["co2_fct_mean"]),
    },
)
co2_metrics = co2_metrics[metrics_selector]
ax = co2_metrics.plot(secondary_y=["MAPE"])

# %%
ax = co2_metrics.groupby(lambda x: x.time()).mean().plot(secondary_y=["MAPE"])
save_ax_for_latex(ax, "dummy_fct_error.pdf")

# %%
co2_metrics.mean()
# Out:
# MAE     70.378841
# MAPE     0.094738
# dtype: float64

# %% [markdown]
# ## Store the data

# %%
scenario_data_fnp = Path().absolute().parent / "source" / "tbmenv" / "data" / "scenario_2_data.csv.bz2"
scenario_data_fnp
# Out:
# PosixPath('/home/jovyan/diss/envs/tbmenv/source/tbmenv/data/scenario_2_data.csv.bz2')

# %%
scenario_data = pd.concat([data, sat_prediction, co2_prediction], axis=1)

_ = scenario_data.pop("minutes of day")

# Adjust the column names to match the notation in the guide paper.
column_name_mapper = {
    "Outside air temperature": "T_a",
    "CO2": "CO2",
    "Supply air temp": "T_s",
    "Zone temperature": "T_z",
    "sat_fct_mean": "T_s_fct_mean",
    "sat_fct_lower": "T_s_fct_lower",
    "sat_fct_upper": "T_s_fct_upper",
    "co2_fct_mean": "CO2_fct_mean",
    "co2_fct_upper": "CO2_fct_upper",
    "co2_fct_lower": "CO2_fct_lower"
}
scenario_data.rename(columns=column_name_mapper, inplace=True)

scenario_data
# Out:
#                       T_a    CO2   T_s   T_z  T_s_fct_mean  T_s_fct_lower  \
# 2014-01-03 04:02:30  26.6  558.6  12.0  28.2     13.079761      11.009006
# 2014-01-03 04:07:30  26.6  557.1  12.0  28.2     13.066577      11.010313
# 2014-01-03 04:12:30  26.6  556.5  12.0  28.2     13.056364      11.009703
# 2014-01-03 04:17:30  26.7  560.1  12.0  28.2     13.072988      11.020608
# 2014-01-03 04:22:30  26.7  559.1  12.0  28.2     13.075183      11.026513
# ...                   ...    ...   ...   ...           ...            ...
# 2014-12-24 16:37:30  29.7  603.9  13.0  24.5     12.984793      10.959290
# 2014-12-24 16:42:30  29.5  603.4  13.0  24.5     13.014742      10.989759
# 2014-12-24 16:47:30  29.5  603.1  13.0  24.5     13.023483      10.993116
# 2014-12-24 16:52:30  29.6  604.5  13.0  24.6     13.031043      10.989980
# 2014-12-24 16:57:30  29.8  605.1  13.0  24.6     13.052815      11.001304
#
#                      T_s_fct_upper  CO2_fct_mean  CO2_fct_upper  CO2_fct_lower
# 2014-01-03 04:02:30      15.150516    589.972304     652.681593     526.068434
# 2014-01-03 04:07:30      15.122841    592.793649     654.406992     525.632715
# 2014-01-03 04:12:30      15.103025    595.280724     665.326650     530.270074
# 2014-01-03 04:17:30      15.125368    597.435199     665.936355     535.553595
# 2014-01-03 04:22:30      15.123854    599.261428     663.173002     535.169819
# ...                            ...           ...            ...            ...
# 2014-12-24 16:37:30      15.010297    772.479135     845.736788     706.495437
# 2014-12-24 16:42:30      15.039724    773.073815     839.562047     706.434503
# 2014-12-24 16:47:30      15.053849    773.784234     837.714528     708.667064
# 2014-12-24 16:52:30      15.072105    774.623347     841.939449     708.443738
# 2014-12-24 16:57:30      15.104327    775.603716     840.276095     708.310219
#
# [18720 rows x 10 columns]

# %%
scenario_data.to_csv(scenario_data_fnp)
